# %% [markdown]
# #Craga de dados camanda bronze - Beneficios

# %%
#  variaveis 
bronze_path   = '/Volumes/workspace/unimed/bronze/'
silver_path   = ''
gold_path     = ''
resource_path = '/Volumes/workspace/unimed/resource/origem/beneficio/'
