# %%
df = spark.sql("select
               nome_beneficio,
               QTEITE,
               VALITE 
               
               
               from unimed.silver.silver_utilizacao_consolidada
               group by nome_beneficio, ANOAUOPCDMDC,
               
               
               
               
               
               
               ")
