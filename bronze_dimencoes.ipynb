# %% [markdown]
# #Craga de dados camanda bronze - Dimencoes

# %% [markdown]
# ###Carga dimencao especialidade médica

# %%
resource_path='/Volumes/unimed/default/resource/origem/dimencoes/GSMiEspecialidade.txt'
df_esp= spark.read.format('csv')\
    .option('header','true')\
    .option('delimiter',';')\
    .option("encoding", "iso-8859-1") \
    .load(resource_path)

# %%
display(df_esp)

# %%
df_esp.printSchema()

# %%
# Salvar como tabela Delta (use mode overwrite se quiser substituir dados existentes)
df_esp.write \
    .format("delta") \
    .mode("overwrite") \
    .option("mergeSchema", "true") \
    .saveAsTable('unimed.bronze.bronze_dimespecialidade')

# %% [markdown]
# ##Carga dimencao Motivo Atendimento

# %%
resource_path='/Volumes/unimed/default/resource/origem/dimencoes/GSMiMotivo_Atendimento.txt'
df_motatend= spark.read.format('csv')\
    .option('header','true')\
    .option('delimiter',';')\
    .option("encoding", "iso-8859-1") \
    .load(resource_path)

# %%
# Salvar como tabela Delta (use mode overwrite se quiser substituir dados existentes)
df_esp.write \
    .format("delta") \
    .mode("overwrite") \
    .option("mergeSchema", "true") \
    .saveAsTable('unimed.bronze.bronze_dimmotivoatendimento')

# %% [markdown]
# ##Carga dimencao Prestador Especialidade

# %%
resource_path='/Volumes/unimed/default/resource/origem/dimencoes/GSMiPrestador_Especialidade.txt'
df_especialidade= spark.read.format('csv')\
    .option('header','true')\
    .option('delimiter',';')\
    .option("encoding", "iso-8859-1") \
    .load(resource_path)

# %%
# Salvar como tabela Delta (use mode overwrite se quiser substituir dados existentes)
df_especialidade.write \
    .format("delta") \
    .mode("overwrite") \
    .option("mergeSchema", "true") \
    .saveAsTable('unimed.bronze.bronze_dimmprestadorespecialidade')

# %% [markdown]
# ##Carga dimencao Tipo Atendimento

# %%
resource_path='/Volumes/unimed/default/resource/origem/dimencoes/GSMiTipo_Atendimento.txt'
df_tipoatend= spark.read.format('csv')\
    .option('header','true')\
    .option('delimiter',';')\
    .option("encoding", "iso-8859-1") \
    .load(resource_path)

# %%
# Salvar como tabela Delta (use mode overwrite se quiser substituir dados existentes)
df_tipoatend.write \
    .format("delta") \
    .mode("overwrite") \
    .option("mergeSchema", "true") \
    .saveAsTable('unimed.bronze.bronze_dimtipoatendimento')

# %%
##Carga dimencao Tipo Beneficio

# %%
resource_path='/Volumes/unimed/default/resource/origem/dimencoes/GSMiTipo_Beneficio.txt'
df_tipobenef= spark.read.format('csv')\
    .option('header','true')\
    .option('delimiter',';')\
    .option("encoding", "iso-8859-1") \
    .load(resource_path)

# %%
# Salvar como tabela Delta (use mode overwrite se quiser substituir dados existentes)
df_tipobenef.write \
    .format("delta") \
    .mode("overwrite") \
    .option("mergeSchema", "true") \
    .saveAsTable('unimed.bronze.bronze_dimtipobeneficio')
